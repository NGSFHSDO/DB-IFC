# %%
import pandas as pd

df = pd.read_excel("data\kospidaq_embeddings.xlsx")
df
# Out:
#          date ticker  broker target_price rating  \
# 0  2025-10-10  현대모비스  한화투자증권      360,000    Buy
# 1  2025-10-10   대웅제약  DS투자증권      210,000     매수
#
#                                              content  embedding_1  \
# 0  [3Q25 Preview] 관세 영향에도 안정적 3Q 매출은 모듈/핵심부품과 A/S...    -0.001488
# 1  3Q25 Pre: 비만패치제, 본 궤도 탑승 별도기준 대웅제약의 3Q25 매출액 및...    -0.006253
#
#    embedding_2  embedding_3  embedding_4  ...  embedding_1527  embedding_1528  \
# 0    -0.009933     0.009638    -0.035406  ...       -0.015297       -0.024625
# 1    -0.019637     0.020031    -0.025595  ...       -0.012112       -0.007118
#
#    embedding_1529  embedding_1530  embedding_1531  embedding_1532  \
# 0        0.033820        0.019464        0.021950       -0.002102
# 1        0.046766        0.008441        0.018212        0.015756
#
#    embedding_1533  embedding_1534  embedding_1535  embedding_1536
# 0       -0.017972        0.015727        0.002831       -0.001401
# ...

# %%
df.dtypes
# Out:
# date               object
# ticker             object
# broker             object
# target_price       object
# rating             object
#                    ...
# embedding_1532    float64
# embedding_1533    float64
# embedding_1534    float64
# embedding_1535    float64
# embedding_1536    float64
# Length: 1542, dtype: object
